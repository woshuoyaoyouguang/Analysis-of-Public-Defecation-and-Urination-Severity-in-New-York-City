# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# df = pd.read_csv("grouped_final.csv")
# df

# %%
df2 = pd.read_excel("grouped_final2_UpSampling.xlsx")
df2
# Out:
#      Zipcode  urination_count  urination_density_pop  urination_density_area  \
# 0      10002              121               0.001488            4.604239e-06
# 1      10003              151               0.002702            9.717875e-06
# 2      10004                9               0.004115            6.639346e-07
# 3      10005               24               0.002960            1.152239e-05
# 4      10007               36               0.004916            6.756920e-06
# ..       ...              ...                    ...                     ...
# 162    11436               10               0.000535            4.405423e-07
# 163    11691               23               0.000382            2.740450e-07
# 164    11692                4               0.000222            1.667195e-07
# 165    11693                3               0.000271            4.704572e-08
# 166    11694               29               0.001438            6.028905e-07
#
#      urination_density_area_degree  PrecentAgeUnder5  PrecentAge5to9  \
# 0                                2             0.030           0.041
# 1                                2             0.028           0.015
# 2                                2             0.033           0.016
# 3                                2             0.055           0.023
# 4                                2             0.099           0.054
# ..                             ...               ...             ...
# 162                              0             0.050           0.063
# 163                              0             0.089           0.092
# 164                              0             0.079           0.074
# 165                              0             0.073           0.070
# 166                              0             0.055           0.046
#
#      PrecentAge10to14  PrecentAge15to19  PrecentAge20to24  ...  shop_count  \
# 0               0.043             0.032             0.062  ...         370
# 1               0.016             0.132             0.106  ...         414
# 2               0.015             0.035             0.026  ...          40
# 3               0.017             0.016             0.116  ...          23
# 4               0.025             0.021             0.052  ...          47
# ..                ...               ...               ...  ...         ...
# 162             0.058             0.061             0.068  ...          13
# 163             0.084             0.068             0.065  ...           7
# 164             0.093             0.050             0.052  ...           5
# 165             0.056             0.048             0.050  ...          17
# 166             0.076             0.046             0.048  ...          55
#
#      shop_density  toilet_count  toilet_density  Median Household Income  \
# 0    1.407908e-05             7    2.663609e-07                    35607
# 1    2.664371e-05             3    1.930704e-07                   129981
# 2    2.950820e-06            22    1.622951e-06                   204949
# 3    1.104229e-05             0    0.000000e+00                   184681
# 4    8.821535e-06             0    0.000000e+00                   250001
# ..            ...           ...             ...                      ...
# 162  5.727050e-07             0    0.000000e+00                    72962
# 163  8.340501e-08             1    1.191500e-08                    52605
# 164  2.083994e-07             2    8.335975e-08                    53077
# 165  2.665924e-07             3    4.704572e-08                    52946
# 166  1.143413e-06             4    8.315731e-08                    87755
#
#      crime_rate  population_density  subway_count          AREA  POPULATION
# 0      0.000209            0.003094            17  2.628013e+07       81305
# 1      0.000501            0.003596            28  1.553838e+07       55878
# 2      0.009145            0.000161            20  1.355555e+07        2187
# 3      0.001727            0.003892            14  2.082901e+06        8107
# 4      0.005053            0.001374            37  5.327871e+06        7323
# ..          ...                 ...           ...           ...         ...
# 162    0.000000            0.000823             0  2.269930e+07       18681
# 163    0.000199            0.000718            12  8.392782e+07       60267
# 164    0.000444            0.000751             8  2.399240e+07       18018
# 165    0.000452            0.000173             5  6.376776e+07       11052
# 166    0.000397            0.000419             8  4.810161e+07       20163
#
# [167 rows x 57 columns]

# %%
df2.describe().T
# Out:
#                                               count          mean  \
# Zipcode                                       167.0  1.083017e+04
# urination_count                               167.0  4.425150e+01
# urination_density_pop                         167.0  1.055621e-03
# urination_density_area                        167.0  1.803914e-06
# urination_density_area_degree                 167.0  2.335329e-01
# PrecentAgeUnder5                              167.0  6.103593e-02
# PrecentAge5to9                                167.0  5.246108e-02
# PrecentAge10to14                              167.0  5.388024e-02
# PrecentAge15to19                              167.0  5.094012e-02
# PrecentAge20to24                              167.0  6.294611e-02
# PrecentAge25to34                              167.0  1.794850e-01
# PrecentAge35to44                              167.0  1.363174e-01
# PrecentAge45to54                              167.0  1.278623e-01
# PrecentAge55to59                              167.0  6.311377e-02
# PrecentAge60to64                              167.0  5.751497e-02
# PrecentAge65to74                              167.0  8.631138e-02
# PrecentAge75to84                              167.0  4.620359e-02
# PrecentAge85andOlder                          167.0  2.214371e-02
# Male Percent                                  167.0  4.784871e-01
# Female Percent                                167.0  5.215129e-01
# PercentWhite                                  167.0  4.351377e-01
# PercetnBlack                                  167.0  2.194072e-01
# PercentAmericanIndianandAlaskaNative          167.0  4.293413e-03
# PercentAsian                                  167.0  1.521976e-01
# PercentNativeHawaiianandOtherPacificIslander  167.0  5.868263e-04
# PercentSomeOtherRace                          167.0  1.323234e-01
# PercentHispanicOrLatino                       167.0  2.677305e-01
# Less Than 9th Grade                           167.0  8.243713e-02
# 9th to 12th Grade, No Diploma                 167.0  7.836527e-02
# High School Graduate                          167.0  2.298204e-01
# Some College, No Degree                       167.0  1.359461e-01
# Associate's Degree                            167.0  6.488623e-02
# Bachelor's Degree                             167.0  2.341976e-01
# Graduate or Professional Degree               167.0  1.744072e-01
# PercentUnder$10,000                           167.0  4.806587e-02
# Percetn$10,000to$14,999                       167.0  3.226946e-02
# Percent$15,000to$24,999                       167.0  6.929341e-02
# Percetn$25,000to$34,999                       167.0  6.993413e-02
# Percent$35,000to$49,999                       167.0  9.777844e-02
# Percetn$50,000to$74,999                       167.0  1.384671e-01
# Percent$75,000to$99,999                       167.0  1.127784e-01
# Percetn$100,000to$149,999                     167.0  1.653234e-01
# Percent$150,000to$199,999                     167.0  9.651497e-02
# Percetn$200,000ormore                         167.0  1.694970e-01
# tree_count                                    167.0  3.877138e+03
# tree_density                                  167.0  9.920051e-05
# green_space_ratio                             167.0  1.381115e-01
# shop_count                                    167.0  8.954491e+01
# shop_density                                  167.0  3.667471e-06
# toilet_count                                  167.0  2.754491e+00
# toilet_density                                167.0  9.065122e-08
# Median Household Income                       167.0  7.829016e+04
# crime_rate                                    167.0  3.466421e-04
# population_density                            167.0  1.537722e-03
# subway_count                                  167.0  1.064671e+01
# AREA                                          167.0  4.365518e+07
# POPULATION                                    167.0  4.695760e+04
#
#                                                        std           min  \
# Zipcode                                       5.741050e+02  1.000200e+04
# urination_count                               4.661502e+01  0.000000e+00
# urination_density_pop                         1.308667e-03  0.000000e+00
# urination_density_area                        2.254428e-06  0.000000e+00
# urination_density_area_degree                 5.023572e-01  0.000000e+00
# PrecentAgeUnder5                              1.727485e-02  1.900000e-02
# POPULATION                                    2.688400e+04  4.174600e+04
#
#                                                        75%           max
# Zipcode                                       1.136250e+04  1.169400e+04
# urination_count                               5.600000e+01  4.250000e+02
# urination_density_pop                         1.184904e-03  1.218324e-02
# urination_density_area                        1.994518e-06  1.152239e-05
# urination_density_area_degree                 0.000000e+00  2.000000e+00
# PrecentAgeUnder5                              6.950000e-02  1.370000e-01
# PrecentAge5to9                                6.300000e-02  1.020000e-01
# PrecentAge10to14                              6.550000e-02  9.300000e-02
# PrecentAge15to19                              6.200000e-02  1.320000e-01
# PrecentAge20to24                              7.300000e-02  1.160000e-01
# PrecentAge25to34                              2.025000e-01  4.270000e-01
# PrecentAge35to44                              1.480000e-01  2.170000e-01
# PrecentAge45to54                              1.400000e-01  2.160000e-01
# PrecentAge55to59                              7.150000e-02  1.010000e-01
# PrecentAge60to64                              6.700000e-02  9.300000e-02
# PrecentAge65to74                              1.030000e-01  1.490000e-01
# PrecentAge75to84                              5.600000e-02  1.240000e-01
# PrecentAge85andOlder                          2.800000e-02  7.300000e-02
# Male Percent                                  4.929734e-01  5.880270e-01
# Female Percent                                5.390356e-01  6.080112e-01
# PercentWhite                                  6.510000e-01  9.370000e-01
# PercetnBlack                                  3.430000e-01  9.100000e-01
# PercentAmericanIndianandAlaskaNative          6.000000e-03  2.900000e-02
# PercentAsian                                  2.315000e-01  7.220000e-01
# PercentNativeHawaiianandOtherPacificIslander  1.000000e-03  8.000000e-03
# PercentSomeOtherRace                          1.815000e-01  5.850000e-01
# PercentHispanicOrLatino                       3.770000e-01  7.780000e-01
# Less Than 9th Grade                           1.125000e-01  2.560000e-01
# 9th to 12th Grade, No Diploma                 1.010000e-01  2.070000e-01
# High School Graduate                          2.910000e-01  4.930000e-01
# Some College, No Degree                       1.700000e-01  2.620000e-01
# Associate's Degree                            8.200000e-02  1.530000e-01
# Bachelor's Degree                             2.920000e-01  5.150000e-01
# Graduate or Professional Degree               2.185000e-01  4.830000e-01
# PercentUnder$10,000                           6.750000e-02  1.910000e-01
# Percetn$10,000to$14,999                       4.400000e-02  1.290000e-01
# Percent$15,000to$24,999                       9.400000e-02  1.930000e-01
# Percetn$25,000to$34,999                       9.500000e-02  1.760000e-01
# Percent$35,000to$49,999                       1.300000e-01  1.850000e-01
# Percetn$50,000to$74,999                       1.715000e-01  2.310000e-01
# Percent$75,000to$99,999                       1.375000e-01  2.020000e-01
# Percetn$100,000to$149,999                     2.075000e-01  2.880000e-01
# Percent$150,000to$199,999                     1.200000e-01  2.170000e-01
# Percetn$200,000ormore                         1.845000e-01  8.130000e-01
# tree_count                                    4.987500e+03  2.218600e+04
# tree_density                                  1.194795e-04  1.939760e-04
# green_space_ratio                             1.758986e-01  1.000000e+00
# shop_count                                    1.295000e+02  6.120000e+02
# shop_density                                  4.887639e-06  3.447999e-05
# toilet_count                                  4.000000e+00  2.200000e+01
# toilet_density                                1.208284e-07  1.622951e-06
# Median Household Income                       9.352700e+04  2.500010e+05
# crime_rate                                    2.981610e-04  9.144947e-03
# population_density                            2.093190e-03  5.240086e-03
# subway_count                                  1.650000e+01  6.100000e+01
# AREA                                          5.827262e+07  2.158358e+08
# POPULATION                                    6.572850e+04  1.090690e+05

# %%
df2.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T
axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

SEED = 2023
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, 
                                                    random_state=SEED)

# %% [markdown]
# #### UP_SAMPLING

# %%
X_train =
# Out:
#      PrecentAgeUnder5  PrecentAge5to9  PrecentAge10to14  PrecentAge15to19  \
# 158             0.073           0.047             0.063             0.076
# 12              0.028           0.013             0.021             0.016
# 128             0.061           0.047             0.052             0.048
# 90              0.063           0.051             0.068             0.056
# 163             0.089           0.092             0.084             0.068
# ..                ...             ...               ...               ...
# 116             0.042           0.053             0.066             0.050
# 3               0.055           0.023             0.017             0.016
# 161             0.076           0.061             0.051             0.048
# 25              0.046           0.040             0.046             0.046
# 87              0.060           0.051             0.048             0.053
#
#      PrecentAge20to24  PrecentAge25to34  PrecentAge35to44  PrecentAge45to54  \
# 158             0.078             0.139             0.119             0.120
# 12              0.072             0.223             0.191             0.125
# 128             0.099             0.131             0.102             0.133
# 90              0.059             0.161             0.129             0.130
# 163             0.065             0.140             0.102             0.116
# ..                ...               ...               ...               ...
# 116             0.059             0.082             0.097             0.103
# 3               0.116             0.427             0.192             0.094
# 161             0.060             0.192             0.135             0.123
# 25              0.078             0.247             0.154             0.121
# 87              0.049             0.160             0.146             0.125
#
#      PrecentAge55to59  PrecentAge60to64  ...  shop_count  shop_density  \
# 158             0.065             0.063  ...         271  4.503339e-06
# 12              0.034             0.055  ...          94  9.597337e-06
# 128             0.066             0.083  ...          18  8.841476e-07
# 90              0.074             0.065  ...          19  4.526816e-07
# 163             0.064             0.048  ...           7  8.340501e-08
# ..                ...               ...  ...         ...           ...
# 116             0.080             0.057  ...          23  5.503095e-07
# 3               0.039             0.011  ...          23  1.104229e-05
# 161             0.069             0.057  ...         109  2.588711e-06
# 25              0.044             0.067  ...          22  1.301609e-06
# 87              0.066             0.066  ...         229  3.959039e-06
#
#      toilet_count  toilet_density  Median Household Income  crime_rate  \
# 158             3    4.985246e-08                    66270    0.000483
# 12              2    2.041987e-07                   130417    0.001005
# 128             0    0.000000e+00                    91795    0.000000
# 90              2    4.765070e-08                    29385    0.000119
# 163             1    1.191500e-08                    52605    0.000199
# ..            ...             ...                      ...         ...
# 116             1    2.392650e-08                    29571    0.000000
# 3               0    0.000000e+00                   184681    0.001727
# 161             1    2.374964e-08                    69873    0.000206
# 25              4    2.366563e-07                    55721    0.000228
# 87              1    1.728838e-08                    79524    0.000159
#
#      population_density  subway_count          AREA  POPULATION
# 158            0.001032            30  6.017758e+07       62075
# 12             0.001625            16  9.794383e+06       15918
# 128            0.000647             0  2.035859e+07       13168
# 90             0.001998            10  4.197210e+07       83866
# 163            0.000718            12  8.392782e+07       60267
# ..                  ...           ...           ...         ...
# 116            0.000301             0  4.179466e+07       12562
# 3              0.003892            14  2.082901e+06        8107
# 161            0.001268            11  4.210590e+07       53404
# 25             0.003373            13  1.690215e+07       57010
# 87             0.001197            11  5.784231e+07       69255
#
# [116 rows x 52 columns]

# %% [markdown]
# # model fine tune
# Hyperparameter Tuning for selected model

# %% [markdown]
# #### decision tree

# %%
# %%time
# Creating a dictionary of parameters to use in GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

dt_params = {
    'criterion':  ['gini', 'entropy'],
    'max_depth':  [None, 2, 4, 6, 8, 10],
    'max_features': [None, 'sqrt', 'log2', 0.2, 0.4, 0.6, 0.8],
    'splitter': ['best', 'random']
}

dt = RandomizedSearchCV(
                   estimator=DecisionTreeClassifier(),
                   param_distributions=dt_params,
                   n_iter = 200,
                   scoring='balanced_accuracy',
#                    scoring='roc_auc',    
                   cv = 5,
                   n_jobs = -1,
                   verbose = 2,
                   random_state = 2022)

dt.fit(X_train, y_train)
print('Best accuracy: %.3f' % dt.best_score_)
print('\nBest params:\n', dt.best_params_)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    4.8s
# Best accuracy: 0.957
#
# Best params:
#  {'splitter': 'best', 'max_features': 0.8, 'max_depth': 10, 'criterion': 'gini'}
# Wall time: 6.26 s
# [Parallel(n_jobs=-1)]: Done 655 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 840 out of 840 | elapsed:    6.1s finished

# %%
import sklearn
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'brier_score_loss',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'v_measure_score']

# %% [markdown]
# #### random forest

# %%
# %%time
# Create the grid parameter:
rf_params = {'n_estimators': [100, 120, 150],
           'criterion': ['entropy', 'gini'], 
           'max_depth': [None,1,3,5,7,9],
           'max_features': range(1,11),  
           'min_samples_split': range(2, 10),
           'min_samples_leaf': [1,3,5]}

# Create the grid:
rf = RandomizedSearchCV(
                  estimator=RandomForestClassifier(),
                  param_distributions= rf_params,
                  n_iter = 200, 
#                   scoring='balanced_accuracy',
                  scoring='accuracy',
                  cv=5, 
                  n_jobs=-1,
                  verbose =2,
                  random_state = 2022)

# Fit using grid search:
rf.fit(X_train, y_train)

# Print best accuracy and best parameters:
print('Best accuracy: %.3f' % rf.best_score_)
print('\nBest params:\n', rf.best_params_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   34.3s
# Best accuracy: 0.977
#
# Best params:
#  {'n_estimators': 120, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 6, 'max_depth': None, 'criterion': 'entropy'}
# Wall time: 55.9 s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:   55.5s finished

# %% [markdown]
# #### xgboost

# %%
# %%time
import xgboost as xgb
# Create the grid parameter:
xgb_params = {'max_depth': [3, 6, 10, 15],
              'learning_rate': [0.01, 0.1, 0.2, 0.3, 0.4], 
              'subsample': np.arange(0.5, 1.0, 0.1),
              'colsample_bytree': np.arange(0.5, 1.0, 0.1),
              'colsample_bylevel': np.arange(0.5, 1.0, 0.1),
              'n_estimators': [100, 250, 500, 750],
              'num_class': [10],
              'tree_method':['auto', 'exact', 'approx', 'hist']}

xgboost = RandomizedSearchCV(
                        estimator=xgb.XGBClassifier(objective='multi:softmax'),
                        param_distributions = xgb_params,
                        n_iter = 200,
                        scoring='accuracy',
#                         scoring='balanced_accuracy',
                        cv=5,
                        n_jobs=-1,
                        verbose=2)

xgboost.fit(X_train, y_train)

# Print best accuracy and best parameters:
print('Best accuracy: %.3f' % xgboost.best_score_)
print('\nBest params:\n', xgboost.best_params_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  3.5min finished
# Best accuracy: 0.983
#
# Best params:
#  {'tree_method': 'auto', 'subsample': 0.5, 'num_class': 10, 'n_estimators': 750, 'max_depth': 6, 'learning_rate': 0.2, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.6}
# Wall time: 3min 33s

# %% [markdown]
# # Final model evaluation

# %%
# %%time
# 选balanced_accuracy作为标准
# Create the final Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt_final = DecisionTreeClassifier(splitter = 'best',
                                  max_features = 0.8,
                                  max_depth = 10,
                                  criterion = 'gini')

# Train the models using 80% of the original data
dt_final.fit(X_train, y_train)

y_pred = dt_final.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('urination_count confusion matrix (0 = low risk, 1 = medium risk, 2 = high risk)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91        38
#            1       0.92      0.65      0.76        17
#            2       1.00      1.00      1.00        20
#
#     accuracy                           0.91        75
#    macro avg       0.93      0.87      0.89        75
# weighted avg       0.91      0.91      0.90        75
#
# Wall time: 119 ms

# %%
# %%time
# 选=accuracy作为标准
# Create the final Decision Tree
dt_final = DecisionTreeClassifier(splitter = 'best',
                                  max_features = 0.2,
                                  max_depth = 10,
                                  criterion = 'gini')

# Train the models using 80% of the original data
dt_final.fit(X_train, y_train)

y_pred = dt_final.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('urination_count confusion matrix (0 = low risk, 1 = medium risk, 2 = high risk)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85        39
#            1       0.25      0.30      0.27        10
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.69        51
#    macro avg       0.38      0.37      0.38        51
# weighted avg       0.73      0.69      0.71        51
#
# Wall time: 190 ms

# %%
# %%time
# 选f1_macro作为标准
# Create the final Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt_final = DecisionTreeClassifier(splitter = 'best',
                                  max_features = 'sqrt',
                                  max_depth = 10,
                                  criterion = 'entropy')

# Train the models using 80% of the original data
dt_final.fit(X_train, y_train)

y_pred = dt_final.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('urination_count confusion matrix (0 = low risk, 1 = medium risk, 2 = high risk)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        39
#            1       0.62      0.80      0.70        10
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.86        51
#    macro avg       0.52      0.57      0.54        51
# weighted avg       0.85      0.86      0.85        51
#
# Wall time: 96 ms

# %%
# %%time
# 选accuracy作为标准
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators = 120,
                             min_samples_split = 6,
                             min_samples_leaf = 1,
                             max_features = 6,
                             max_depth = None,
                             criterion = 'entropy')
# Fit RandomForestClassifier
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('urination_count confusion matrix (0 = low risk, 1 = medium risk, 2 = high risk)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        38
#            1       1.00      0.76      0.87        17
#            2       1.00      1.00      1.00        20
#
#     accuracy                           0.95        75
#    macro avg       0.97      0.92      0.94        75
# weighted avg       0.95      0.95      0.94        75
#
# Wall time: 243 ms

# %%
# %%time
# 选accuracy作为标准
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators = 100,
                             min_samples_split = 7,
                             min_samples_leaf = 1,
                             max_features = 10,
                             max_depth = 3,
                             criterion = 'gini')
# Fit RandomForestClassifier
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('urination_count confusion matrix (0 = low risk, 1 = medium risk, 2 = high risk)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93        38
#            1       1.00      0.59      0.74        17
#            2       0.95      1.00      0.98        20
#
#     accuracy                           0.91        75
#    macro avg       0.94      0.86      0.88        75
# weighted avg       0.92      0.91      0.90        75
#
# Wall time: 306 ms

# %%
# %%time
# 选balanced_accuracy作为标准
import xgboost as xgb
xgb_model = xgb.XGBClassifier(tree_method = 'hist',
                              subsample = 0.89,
                              num_class = 10,
                              n_estimators = 500, 
                              max_depth = 15, 
                              learning_rate = 0.3,
                              colsample_bytree = 0.7,
                              colsample_bylevel = 0.89)

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('urination_count confusion matrix (0 = low risk, 1 = medium risk, 2 = high risk)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        39
#            1       0.67      0.80      0.73        10
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.88        51
#    macro avg       0.54      0.58      0.56        51
# weighted avg       0.86      0.88      0.87        51
#
# Wall time: 889 ms

# %%
# %%time
# 选accuracy作为标准
import xgboost as xgb
xgb_model = xgb.XGBClassifier(tree_method= 'auto',
                              subsample= 0.5,
                              num_class= 10,
                              n_estimators= 750,
                              max_depth= 6,
                              learning_rate= 0.2,
                              colsample_bytree= 0.7,
                              colsample_bylevel= 0.6)

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('urination_count confusion matrix (0 = low risk, 1 = medium risk, 2 = high risk)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        38
#            1       1.00      0.76      0.87        17
#            2       1.00      1.00      1.00        20
#
#     accuracy                           0.95        75
#    macro avg       0.97      0.92      0.94        75
# weighted avg       0.95      0.95      0.94        75
#
# Wall time: 1.2 s

# %%
# # K-Fold Cross-Validation
# from sklearn.model_selection import cross_validate
# def cross_validation(model, _X, _y, _cv=5):
#       '''Function to perform 5 Folds Cross-Validation
#        Parameters
#        ----------
#       model: Python Class, default=None
#               This is the machine learning algorithm to be used for training.
#       _X: array
#            This is the matrix of features.
#       _y: array
#            This is the target variable.
#       _cv: int, default=5
#           Determines the number of folds for cross-validation.
#        Returns
#        -------
#        The function returns a dictionary containing the metrics 'accuracy', 'precision',
#        'recall', 'f1' for both training set and validation set.
#       '''
#       _scoring = ['f1_weighted','recall_weighted','accuracy','precision_weighted']
#       results = cross_validate(estimator=model,
#                                X=_X,
#                                y=_y,
#                                cv=_cv,
#                                scoring=_scoring,
#                                return_train_score=True)
      
#       return {
#              "Training Accuracy scores": results['train_accuracy'],
# #               "Mean Training Accuracy": results['train_accuracy'].mean()*100,
#               "Training Precision scores": results['train_precision_weighted'],
# #               "Mean Training Precision": results['train_precision_weighted'].mean(),
#               "Training Recall scores": results['train_recall_weighted'],
# #               "Mean Training Recall": results['train_recall_weighted'].mean(),
#               "Training F1 scores": results['train_f1_weighted'],
# #               "Mean Training F1 Score": results['train_f1_weighted'].mean(),
#               "Test Accuracy scores": results['test_accuracy'],
# #               "Mean Test Accuracy": results['test_accuracy'].mean()*100,
#               "Test Precision scores": results['test_precision_weighted'],
# #               "Mean Test Precision": results['test_precision_weighted'].mean(),
#               "Test Recall scores": results['test_recall_weighted'],
# #               "Mean Test Recall": results['test_recall_weighted'].mean(),
#               "Test F1 scores": results['test_f1_weighted'],
# #               "Mean Test F1 Score": results['test_f1_weighted'].mean()
#               }

# %%
# # Grouped Bar Chart for both training and validation data
# def plot_result(x_label, y_label, plot_title, train_data, val_data):
#         '''Function to plot a grouped bar chart showing the training and validation
#           results of the ML model in each fold after applying K-fold cross-validation.
#          Parameters
#          ----------
#          x_label: str, 
#             Name of the algorithm used for training e.g 'Decision Tree'
          
#          y_label: str, 
#             Name of metric being visualized e.g 'Accuracy'
#          plot_title: str, 
#             This is the title of the plot e.g 'Accuracy Plot'
         
#          train_result: list, array
#             This is the list containing either training precision, accuracy, or f1 score.
        
#          val_result: list, array
#             This is the list containing either validation precision, accuracy, or f1 score.
#          Returns
#          -------
#          The function returns a Grouped Barchart showing the training and validation result
#          in each fold.
#         '''
        
#         # Set size of plot
#         plt.figure(figsize=(12,6))
#         labels = ["1st Fold", "2nd Fold", "3rd Fold", "4th Fold", "5th Fold"]
#         X_axis = np.arange(len(labels))
#         ax = plt.gca()
#         plt.ylim(0.40000, 1)
#         plt.bar(X_axis-0.2, train_data, 0.4, color='lightblue', label='Training')
#         plt.bar(X_axis+0.2, val_data, 0.4, color='tomato', label='Test')
#         plt.title(plot_title, fontsize=30)
#         plt.xticks(X_axis, labels)
#         plt.xlabel(x_label, fontsize=14)
#         plt.ylabel(y_label, fontsize=14)
#         plt.ylim((0,1))
#         plt.legend()
#         plt.grid(True)
#         plt.show()

# %%
# from sklearn.ensemble import RandomForestClassifier

# model_name = "RandomForest"
# model = RandomForestClassifier(n_estimators = 80, random_state = SEED)



# model_result = cross_validation(model, X, y, 5)

# pd.DataFrame.from_dict(model_result)
# pd.DataFrame.from_dict(model_result).mean(axis=0)
# Out:
# Training Accuracy scores     1.000000
# Training Precision scores    1.000000
# Training Recall scores       1.000000
# Training F1 scores           1.000000
# Test Accuracy scores         0.729004
# Test Precision scores        0.754508
# Test Recall scores           0.729004
# Test F1 scores               0.724711
# dtype: float64

# %%
# # Plot Accuracy Result

# plot_result(model_name,
#             "Accuracy",
#             "Accuracy scores in 5 Folds",
#             model_result["Training Accuracy scores"],
#             model_result["Test Accuracy scores"])

# %%
# # Plot Precision Result
# plot_result(model_name,
#             "Precision",
#             "Precision scores in 5 Folds",
#             model_result["Training Precision scores"],
#             model_result["Test Precision scores"])

# %%
# # Plot Recall Result
# plot_result(model_name,
#             "Recall",
#             "Recall scores in 5 Folds",
#             model_result["Training Recall scores"],
#             model_result["Test Recall scores"])

# %%
# # Plot F1-Score Result
# plot_result(model_name,
#             "F1",
#             "F1 Scores in 5 Folds",
#             model_result["Training F1 scores"],
#             model_result["Test F1 scores"])

# %%
# import xgboost as xgb

# model_name = "XGBoost"
# model = xgb.XGBClassifier(objective="multi:softprob", random_state=SEED)
# model_result = cross_validation(model, X, y, 5)

# pd.DataFrame.from_dict(model_result)
# # pd.DataFrame.from_dict(model_result).mean(axis=0)
# Out:
#    Training Accuracy scores  Training Precision scores  \
# 0                       1.0                        1.0
# 1                       1.0                        1.0
# 2                       1.0                        1.0
# 3                       1.0                        1.0
# 4                       1.0                        1.0
#
#    Training Recall scores  Training F1 scores  Test Accuracy scores  \
# 0                     1.0                 1.0              0.885714
# 1                     1.0                 1.0              0.787879
# 2                     1.0                 1.0              0.606061
# 3                     1.0                 1.0              0.727273
# 4                     1.0                 1.0              0.575758
#
#    Test Precision scores  Test Recall scores  Test F1 scores
# 0               0.904082            0.885714        0.884735
# 1               0.795940            0.787879        0.783054
# 2               0.601852            0.606061        0.601449
# 3               0.733838            0.727273        0.729594
# 4               0.675926            0.575758        0.540658

# %%
# # Plot Accuracy Result

# plot_result(model_name,
#             "Accuracy",
#             "Accuracy scores in 5 Folds",
#             model_result["Training Accuracy scores"],
#             model_result["Test Accuracy scores"])
